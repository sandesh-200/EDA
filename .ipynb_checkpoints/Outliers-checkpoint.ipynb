# %% [markdown]
# ### 3-Sigma Technique (Standard Deviation)

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics
import pandas as pd

# %%
data  = pd.read_csv('raw_sales.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head(5)
# Out:
#               datesold  postcode   price propertyType  bedrooms
# 0  2007-02-07 00:00:00      2607  525000        house         4
# 1  2007-02-27 00:00:00      2906  290000        house         3
# 2  2007-03-07 00:00:00      2905  328000        house         3
# 3  2007-03-09 00:00:00      2905  380000        house         4
# 4  2007-03-21 00:00:00      2906  310000        house         3

# %%
# Function to Detection Outlier on one-dimentional datasets.
def find_anomilies(data):
    anomilies = []
    # Set upper and lower limit to 3 standard deviation
    random_data_std = statistics.stdev(data)
    random_data_mean = statistics.mean(data)

    # 3-standard deviation
    anomaly_cut_off = random_data_std * 3

    lower_limit = random_data_mean - anomaly_cut_off
    upper_limit = random_data_mean + anomaly_cut_off

    # Generate outliers
    for outlier in data:
        if outlier > upper_limit or outlier<lower_limit:
            anomilies.append(outlier)
    return anomilies

# %%
data.price
# Out:
# 0        525000
# 1        290000
# 2        328000
# 3        380000
# 4        310000
#           ...
# 29575    500000
# 29576    560000
# 29577    464950
# 29578    589000
# 29579    775000
# Name: price, Length: 29580, dtype: int64

# %%
list_1 = find_anomilies(data['price'])

# %%
len(list_1)
# Out:
# 461

# %%
data.price.skew()
# Out:
# np.float64(4.312009366902367)

# %%
import seaborn as sns

# %%
sns.kdeplot(data.price)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
data['price_transformed'] = np.log(data.price)

# %%
data.price_transformed.skew()
# Out:
# np.float64(0.47316462699847633)

# %%
list_2 = find_anomilies(data.price_transformed)

# %%
len(list_2)
# Out:
# 266

# %%
sns.kdeplot(data.price_transformed)
# Out:
# <Axes: xlabel='price_transformed', ylabel='Density'>

# %%
data['price_transformed_double'] = np.log(data.price_transformed)

# %%
data.price_transformed_double.skew()
# Out:
# np.float64(0.33092530655758595)

# %%
list_3 = find_anomilies(data.price_transformed_double)

# %%
len(list_3)
# Out:
# 251

# %%
sns.kdeplot(data.price_transformed_double)
# Out:
# <Axes: xlabel='price_transformed_double', ylabel='Density'>

# %% [markdown]
# ## Boxplots

# %%
sns.boxplot(data=data)
# Out:
#   Cell In[22], line 1
#     sns.
#         ^
# SyntaxError: invalid syntax
